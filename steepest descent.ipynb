# %%
import menpo.io as mio

image1 = mio.import_builtin_asset.takeo_ppm()
image1.crop_to_landmarks_proportion_inplace(0.3)
image1 = image1.as_greyscale()

image2 = mio.import_builtin_asset.breakingbad_jpg()
image2.crop_to_landmarks_proportion_inplace(0.3)

# %matplotlib inline
image2.view_landmarks()

# %%
from cvpr15.utils import build_patches_image, vectorize_patches_image
from menpo.image import Image

def warp2(image, centres, patch_shape):
    r"""
    Warp function F: It extracts the patches around each shape point
    returns an image object of size:
    n_points x patch_shape[0] x patch_shape[1] x n_channels
    """
    return build_patches_image(image, centres, patch_shape)

def vectorize2(patches_image):
    r"""
    Vectorization function A: It vectorizes a given patches image.
    Returns an ndarray of size (m*n) x 1
    """
    return vectorize_patches_image(patches_image)

def gradient2(patches):
    r"""
    Returns the gradients of the patches
    n_dims x n_channels x n_points x (w x h)
    """
    n_points = patches.pixels.shape[0]
    h = patches.pixels.shape[1]
    w = patches.pixels.shape[2]
    n_channels = patches.pixels.shape[3]
    
    # initial patches: n_parts x height x width x n_channels
    pixels = patches.pixels
    # move parts axis to end: height x width x n_channels x n_parts
    pixels = np.rollaxis(pixels, 0, pixels.ndim)
    # merge channels and parts axes: height x width x (n_channels * n_parts)
    pixels = np.reshape(pixels, (h, w, -1), order='F')
    # compute and vectorize gradient: (height * width) x (n_channels * n_parts * n_dims)
    g = Image(pixels).gradient().as_vector(keep_channels=True)
    # reshape gradient: (height * width) x n_parts x n_channels x n_dims
    # then trnspose it: n_dims x n_channels x n_parts x (height * width)
    return np.reshape(g, (-1, n_points, n_channels, 2)).T

# %%
# %matplotlib inline
import menpo.io as mio
from menpo.feature import no_op, igo, hog, sparse_hog

# method to load a database
def load_database(path_to_images, crop_percentage, max_images=None):
    images = []
    # load landmarked images
    for i in mio.import_images(path_to_images, max_images=max_images, verbose=True):
        # crop image
        i.crop_to_landmarks_proportion_inplace(crop_percentage)
        
        # convert it to grayscale if needed
        if i.n_channels == 4:
            i = i.as_greyscale(mode='luminosity')
            
        # append it to the list
        images.append(i)
    return images

# %%
import numpy as np
from cvpr15 import APSBuilder
from cvpr15.fitter import LucasKanadeAPSFitter
from cvpr15.algorithm import Forward

training_images = load_database('/mnt/data/nontas/trainset/', 0.5)

adjacency_array = np.empty((67, 2), dtype=np.int32)
for i in range(68):
    if i < 34:
        adjacency_array[i, 0] = 34
        adjacency_array[i, 1] = i
    elif i > 34:
        adjacency_array[i-1, 0] = 34
        adjacency_array[i-1, 1] = i

root_vertex = 34

aps = APSBuilder(adjacency_array=adjacency_array, 
                 root_vertex=0, 
                 features=no_op, 
                 patch_shape=(6, 6),
                 normalization_diagonal=100,
                 n_levels=1, 
                 downscale=2, 
                 scaled_shape_models=True,
                 max_shape_components=None,
                 n_appearance_parameters=100).build(training_images, verbose=True)

fitter = LucasKanadeAPSFitter(aps, 
                              algorithm=Forward, 
                              n_shape=3)

ds_dp = np.rollaxis(fitter._fitters[0].transform.d_dp(None), -1)
print ds_dp.shape
# Out:
# - Loading 21 assets: [                    ] 4%
# - Loading 21 assets: [=                   ] 9%
# - Loading 21 assets: [==                  ] 14%
# - Loading 21 assets: [===                 ] 19%
# - Loading 21 assets: [====                ] 23%
# - Loading 21 assets: [=====               ] 28%
# - Loading 21 assets: [======              ] 33%
# - Loading 21 assets: [=======             ] 38%
# - Loading 21 assets: [========            ] 42%
# - Loading 21 assets: [=========           ] 47%
# - Loading 21 assets: [==========          ] 52%
# - Loading 21 assets: [===========         ] 57%
# - Loading 21 assets: [============        ] 61%
# - Loading 21 assets: [=============       ] 66%
# - Loading 21 assets: [==============      ] 71%
# - Loading 21 assets: [===============     ] 76%
# - Loading 21 assets: [================    ] 80%
# - Loading 21 assets: [=================   ] 85%
# - Loading 21 assets: [==================  ] 90%
# - Loading 21 assets: [=================== ] 95%
# - Loading 21 assets: [====================] 100%
# - Computing reference shape
# - Normalizing images size: 4%
# - Normalizing images size: 9%
# - Normalizing images size: 14%
# - Normalizing images size: 19%
# - Normalizing images size: 23%
# - Normalizing images size: 28%
# - Normalizing images size: 33%
# - Normalizing images size: 38%
# - Normalizing images size: 42%
# - Normalizing images size: 47%
# - Normalizing images size: 52%
# - Normalizing images size: 57%
# - Normalizing images size: 61%
# - Normalizing images size: 66%
# - Normalizing images size: 71%
# - Normalizing images size: 76%
# - Normalizing images size: 80%
# - Normalizing images size: 85%
# - Normalizing images size: 90%
# - Normalizing images size: 95%
# - Normalizing images size: 100%
# - Normalizing images size: Done
# Computing top level feature space - 4%
# Computing top level feature space - 9%
# Computing top level feature space - 14%
# Computing top level feature space - 19%
# Computing top level feature space - 23%
# Computing top level feature space - 28%
# Computing top level feature space - 33%
# Computing top level feature space - 38%
# Computing top level feature space - 42%
# Computing top level feature space - 47%
# Computing top level feature space - 52%
# Computing top level feature space - 57%
# Computing top level feature space - 61%
# Computing top level feature space - 66%
# Computing top level feature space - 71%
# Computing top level feature space - 76%
# Computing top level feature space - 80%
# Computing top level feature space - 85%
# Computing top level feature space - 90%
# Computing top level feature space - 95%
# Computing top level feature space - 100%
# - Building model
#   - Computing feature space/rescaling - 4%
#   - Computing feature space/rescaling - 9%
#   - Computing feature space/rescaling - 14%
#   - Computing feature space/rescaling - 19%
#   - Computing feature space/rescaling - 23%
#   - Computing feature space/rescaling - 28%
#   - Computing feature space/rescaling - 33%
#   - Computing feature space/rescaling - 38%
#   - Computing feature space/rescaling - 42%
#   - Computing feature space/rescaling - 47%
#   - Computing feature space/rescaling - 52%
#   - Computing feature space/rescaling - 57%
#   - Computing feature space/rescaling - 61%
#   - Computing feature space/rescaling - 66%
#   - Computing feature space/rescaling - 71%
#   - Computing feature space/rescaling - 76%
#   - Computing feature space/rescaling - 80%
#   - Computing feature space/rescaling - 85%
#   - Computing feature space/rescaling - 90%
#   - Computing feature space/rescaling - 95%
#   - Computing feature space/rescaling - 100%
#   - Building shape model
#   - Computing relative locations from shapes - 4%
#   - Computing relative locations from shapes - 9%
#   - Computing relative locations from shapes - 14%
#   - Computing relative locations from shapes - 19%
#   - Computing relative locations from shapes - 23%
#   - Computing relative locations from shapes - 28%
#   - Computing relative locations from shapes - 33%
#   - Computing relative locations from shapes - 38%
#   - Computing relative locations from shapes - 42%
#   - Computing relative locations from shapes - 47%
#   - Computing relative locations from shapes - 52%
#   - Computing relative locations from shapes - 57%
#   - Computing relative locations from shapes - 61%
#   - Computing relative locations from shapes - 66%
#   - Computing relative locations from shapes - 71%
#   - Computing relative locations from shapes - 76%
#   - Computing relative locations from shapes - 80%
#   - Computing relative locations from shapes - 85%
#   - Computing relative locations from shapes - 90%
#   - Computing relative locations from shapes - 95%
#   - Computing relative locations from shapes - 100%
#   - Training deformation distribution per tree edge
#   - Training deformation distribution per edge - 1%
#   - Training deformation distribution per edge - 2%
#   - Training deformation distribution per edge - 4%
#   - Training deformation distribution per edge - 5%
#   - Training deformation distribution per edge - 7%
#   - Training deformation distribution per edge - 8%
#   - Training deformation distribution per edge - 10%
#   - Training deformation distribution per edge - 11%
#   - Training deformation distribution per edge - 13%
#   - Training deformation distribution per edge - 14%
#   - Training deformation distribution per edge - 16%
#   - Training deformation distribution per edge - 17%
#   - Training deformation distribution per edge - 19%
#   - Training deformation distribution per edge - 20%
#   - Training deformation distribution per edge - 22%
#   - Training deformation distribution per edge - 23%
#   - Training deformation distribution per edge - 25%
#   - Training deformation distribution per edge - 26%
#   - Training deformation distribution per edge - 28%
#   - Training deformation distribution per edge - 29%
#   - Training deformation distribution per edge - 31%
#   - Training deformation distribution per edge - 32%
#   - Training deformation distribution per edge - 34%
#   - Training deformation distribution per edge - 35%
#   - Training deformation distribution per edge - 37%
#   - Training deformation distribution per edge - 38%
#   - Training deformation distribution per edge - 40%
#   - Training deformation distribution per edge - 41%
#   - Training deformation distribution per edge - 43%
#   - Training deformation distribution per edge - 44%
#   - Training deformation distribution per edge - 46%
#   - Training deformation distribution per edge - 47%
#   - Training deformation distribution per edge - 49%
#   - Training deformation distribution per edge - 50%
#   - Training deformation distribution per edge - 52%
#   - Training deformation distribution per edge - 53%
#   - Training deformation distribution per edge - 55%
#   - Training deformation distribution per edge - 56%
#   - Training deformation distribution per edge - 58%
#   - Training deformation distribution per edge - 59%
#   - Training deformation distribution per edge - 61%
#   - Training deformation distribution per edge - 62%
#   - Training deformation distribution per edge - 64%
#   - Training deformation distribution per edge - 65%
#   - Training deformation distribution per edge - 67%
#   - Training deformation distribution per edge - 68%
#   - Training deformation distribution per edge - 70%
#   - Training deformation distribution per edge - 71%
#   - Training deformation distribution per edge - 73%
#   - Training deformation distribution per edge - 74%
#   - Training deformation distribution per edge - 76%
#   - Training deformation distribution per edge - 77%
#   - Training deformation distribution per edge - 79%
#   - Training deformation distribution per edge - 80%
#   - Training deformation distribution per edge - 82%
#   - Training deformation distribution per edge - 83%
#   - Training deformation distribution per edge - 85%
#   - Training deformation distribution per edge - 86%
#   - Training deformation distribution per edge - 88%
#   - Training deformation distribution per edge - 89%
#   - Training deformation distribution per edge - 91%
#   - Training deformation distribution per edge - 92%
#   - Training deformation distribution per edge - 94%
#   - Training deformation distribution per edge - 95%
#   - Training deformation distribution per edge - 97%
#   - Training deformation distribution per edge - 98%
#   - Training deformation distribution per edge - 100%
#   - Extracting patches from images - 4%
#   - Extracting patches from images - 9%
#   - Extracting patches from images - 14%
#   - Extracting patches from images - 19%
#   - Extracting patches from images - 23%
#   - Extracting patches from images - 28%
#   - Extracting patches from images - 33%
#   - Extracting patches from images - 38%
#   - Extracting patches from images - 42%
#   - Extracting patches from images - 47%
#   - Extracting patches from images - 52%
#   - Extracting patches from images - 57%
#   - Extracting patches from images - 61%
#   - Extracting patches from images - 66%
#   - Extracting patches from images - 71%
#   - Extracting patches from images - 76%
#   - Extracting patches from images - 80%
#   - Extracting patches from images - 85%
#   - Extracting patches from images - 90%
#   - Extracting patches from images - 95%
#   - Extracting patches from images - 100%
#   - Training appearance distribution per patch
#   - Training appearance distribution per patch - 1%
#   - Training appearance distribution per patch - 2%
#   - Training appearance distribution per patch - 4%
#   - Training appearance distribution per patch - 5%
#   - Training appearance distribution per patch - 7%
#   - Training appearance distribution per patch - 8%
#   - Training appearance distribution per patch - 10%
#   - Training appearance distribution per patch - 11%
#   - Training appearance distribution per patch - 13%
#   - Training appearance distribution per patch - 14%
#   - Training appearance distribution per patch - 16%
#   - Training appearance distribution per patch - 17%
#   - Training appearance distribution per patch - 19%
#   - Training appearance distribution per patch - 20%
#   - Training appearance distribution per patch - 22%
#   - Training appearance distribution per patch - 23%
#   - Training appearance distribution per patch - 25%
#   - Training appearance distribution per patch - 26%
#   - Training appearance distribution per patch - 27%
#   - Training appearance distribution per patch - 29%
#   - Training appearance distribution per patch - 30%
#   - Training appearance distribution per patch - 32%
#   - Training appearance distribution per patch - 33%
#   - Training appearance distribution per patch - 35%
#   - Training appearance distribution per patch - 36%
#   - Training appearance distribution per patch - 38%
#   - Training appearance distribution per patch - 39%
#   - Training appearance distribution per patch - 41%
#   - Training appearance distribution per patch - 42%
#   - Training appearance distribution per patch - 44%
#   - Training appearance distribution per patch - 45%
#   - Training appearance distribution per patch - 47%
#   - Training appearance distribution per patch - 48%
#   - Training appearance distribution per patch - 50%
#   - Training appearance distribution per patch - 51%
#   - Training appearance distribution per patch - 52%
#   - Training appearance distribution per patch - 54%
#   - Training appearance distribution per patch - 55%
#   - Training appearance distribution per patch - 57%
#   - Training appearance distribution per patch - 58%
#   - Training appearance distribution per patch - 60%
#   - Training appearance distribution per patch - 61%
#   - Training appearance distribution per patch - 63%
#   - Training appearance distribution per patch - 64%
#   - Training appearance distribution per patch - 66%
#   - Training appearance distribution per patch - 67%
#   - Training appearance distribution per patch - 69%
#   - Training appearance distribution per patch - 70%
#   - Training appearance distribution per patch - 72%
#   - Training appearance distribution per patch - 73%
#   - Training appearance distribution per patch - 75%
#   - Training appearance distribution per patch - 76%
#   - Training appearance distribution per patch - 77%
#   - Training appearance distribution per patch - 79%
#   - Training appearance distribution per patch - 80%
#   - Training appearance distribution per patch - 82%
#   - Training appearance distribution per patch - 83%
#   - Training appearance distribution per patch - 85%
#   - Training appearance distribution per patch - 86%
#   - Training appearance distribution per patch - 88%
#   - Training appearance distribution per patch - 89%
#   - Training appearance distribution per patch - 91%
#   - Training appearance distribution per patch - 92%
#   - Training appearance distribution per patch - 94%
#   - Training appearance distribution per patch - 95%
#   - Training appearance distribution per patch - 97%
#   - Training appearance distribution per patch - 98%
#   - Training appearance distribution per patch - 100%
#   - Done
# (2, 68, 7)

# %%
def steepest_descent_images(gradient, ds_dp):
    # compute steepest descent images
    # gradient: n_dims x n_channels x n_parts x (w x h)
    # ds_dp:    n_dims x            x n_parts x         x n_params
    # sdi:               n_channels x n_parts x (w x h) x n_params
    sdi = 0
    a = gradient[..., None] * ds_dp[..., None, :, None, :]
    for d in a:
        sdi += d

    # reshape steepest descent images
    # sdi: (n_channels x n_parts x w x h) x n_params
    sdi = sdi.reshape((-1, sdi.shape[3]))
    sdi = sdi.reshape((gradient.shape[1], gradient.shape[2], -1, sdi.shape[-1]))
    sdi = np.rollaxis(sdi, -2, 0)
    return sdi.reshape((-1, sdi.shape[3]))

# %%
image = image2
patch_shape = (17, 17)
n_channels = image.n_channels

# %%
i2 = warp2(image, image.landmarks['PTS']['all'], patch_shape)
vec_i2 = vectorize2(i2)
#e1 = vec_i1 - self.appearance_model[0]
gradient = gradient2(i2)
print vec_i2.shape
print gradient.shape
# Out:
# (58956,)
# (2, 3, 68, 289)

# %%
k = 37
c = 2

l = np.prod(patch_shape)
from_i = k * l + c * l
to_i = k * l + (c+1) * l
Image(vec_i2[from_i:to_i].reshape(patch_shape[0], patch_shape[1], n_channels)).view()

d = 0
c = 2
Image(gradient[d, c, k, :].reshape(patch_shape[0], patch_shape[1])).view_new()

# %%
# compute steepest descent images
# gradient: n_dims x n_channels x n_parts x (w x h)
# ds_dp:    n_dims x            x n_parts x         x n_params
# sdi:               n_channels x n_parts x (w x h) x n_params
sdi = 0
a = gradient[..., None] * ds_dp[..., None, :, None, :]
for d in a:
    sdi += d

sdi = sdi.reshape((-1, sdi.shape[3]))
sdi = sdi.reshape((gradient.shape[1], gradient.shape[2], -1, sdi.shape[-1]))
sdi2 = np.rollaxis(sdi, -2, 0)
print sdi2.shape
sdi = sdi2.reshape((-1, sdi2.shape[3]))
print sdi.shape

#sdi = sdi.reshape(3, 68, 17, 17, 7)
#sdi = np.rollaxis(sdi, 3, 0)
#sdi = np.rollaxis(sdi, 3, 1)
Image(sdi2[:, 1, 37, 0].reshape(17, 17, 1)).view()

k = 37

l = np.prod(patch_shape) * n_channels
from_i = k * l
to_i = (k+1) * l
Image(sdi[from_i:to_i, 0].reshape(patch_shape[0], patch_shape[1], n_channels)).view_new()
# Out:
# (289, 3, 68, 7)
# (58956, 7)

# %%
# %matplotlib inline
from menpo.image import Image
k = 37
from_i = k * 17 * 17 * n_channels
to_i = (k+1) * 17 * 17 * n_channels
Image(sd[from_i:to_i, 0].reshape((17, 17, n_channels), order='C')).view()
