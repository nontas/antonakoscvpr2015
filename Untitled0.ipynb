# %%
import menpo.io as mio

# method to load a database
def load_database(path_to_images, crop_percentage, max_images=None):
    images = []
    # load landmarked images
    for i in mio.import_images(path_to_images, max_images=max_images, verbose=True):
        # crop image
        i.crop_to_landmarks_proportion_inplace(crop_percentage)
        
        # convert it to grayscale if needed
        if i.n_channels == 3:
            i = i.as_greyscale(mode='luminosity')
            
        # append it to the list
        images.append(i)
    return images

# %%
#training_images = load_database('/mnt/data/nontas/trainset/', 0.1)
training_images = load_database('/mnt/data/nontas/train200/', 0.5)
# Out:
# - Loading 200 assets: [                    ] 0%
# - Loading 200 assets: [                    ] 1%
# - Loading 200 assets: [                    ] 1%
# - Loading 200 assets: [                    ] 2%
# - Loading 200 assets: [                    ] 2%
# - Loading 200 assets: [                    ] 3%
# - Loading 200 assets: [                    ] 3%
# - Loading 200 assets: [                    ] 4%
# - Loading 200 assets: [                    ] 4%
# - Loading 200 assets: [=                   ] 5%
# - Loading 200 assets: [=                   ] 5%
# - Loading 200 assets: [=                   ] 6%
# - Loading 200 assets: [=                   ] 6%
# - Loading 200 assets: [=                   ] 7%
# - Loading 200 assets: [=                   ] 7%
# - Loading 200 assets: [=                   ] 8%
# - Loading 200 assets: [=                   ] 8%
# - Loading 200 assets: [=                   ] 9%
# - Loading 200 assets: [=                   ] 9%
# - Loading 200 assets: [==                  ] 10%
# - Loading 200 assets: [==                  ] 10%
# - Loading 200 assets: [==                  ] 11%
# - Loading 200 assets: [==                  ] 11%
# - Loading 200 assets: [==                  ] 12%
# - Loading 200 assets: [==                  ] 12%
# - Loading 200 assets: [==                  ] 13%
# - Loading 200 assets: [==                  ] 13%
# - Loading 200 assets: [==                  ] 14%
# - Loading 200 assets: [==                  ] 14%
# - Loading 200 assets: [===                 ] 15%
# - Loading 200 assets: [===                 ] 15%
# - Loading 200 assets: [===                 ] 16%
# - Loading 200 assets: [===                 ] 16%
# - Loading 200 assets: [===                 ] 17%
# - Loading 200 assets: [===                 ] 17%
# - Loading 200 assets: [===                 ] 18%
# - Loading 200 assets: [===                 ] 18%
# - Loading 200 assets: [===                 ] 19%
# - Loading 200 assets: [===                 ] 19%
# - Loading 200 assets: [====                ] 20%
# - Loading 200 assets: [====                ] 20%
# - Loading 200 assets: [====                ] 21%
# - Loading 200 assets: [====                ] 21%
# - Loading 200 assets: [====                ] 22%
# - Loading 200 assets: [====                ] 22%
# - Loading 200 assets: [====                ] 23%
# - Loading 200 assets: [====                ] 23%
# - Loading 200 assets: [====                ] 24%
# - Loading 200 assets: [====                ] 24%
# - Loading 200 assets: [=====               ] 25%
# - Loading 200 assets: [=====               ] 25%
# - Loading 200 assets: [=====               ] 26%
# - Loading 200 assets: [=====               ] 26%
# - Loading 200 assets: [=====               ] 27%
# - Loading 200 assets: [=====               ] 27%
# - Loading 200 assets: [=====               ] 28%
# - Loading 200 assets: [=====               ] 28%
# - Loading 200 assets: [=====               ] 28%
# - Loading 200 assets: [=====               ] 29%
# - Loading 200 assets: [======              ] 30%
# - Loading 200 assets: [======              ] 30%
# - Loading 200 assets: [======              ] 31%
# - Loading 200 assets: [======              ] 31%
# - Loading 200 assets: [======              ] 32%
# - Loading 200 assets: [======              ] 32%
# - Loading 200 assets: [======              ] 33%
# - Loading 200 assets: [======              ] 33%
# - Loading 200 assets: [======              ] 34%
# - Loading 200 assets: [======              ] 34%
# - Loading 200 assets: [=======             ] 35%
# - Loading 200 assets: [=======             ] 35%
# - Loading 200 assets: [=======             ] 36%
# - Loading 200 assets: [=======             ] 36%
# - Loading 200 assets: [=======             ] 37%
# - Loading 200 assets: [=======             ] 37%
# - Loading 200 assets: [=======             ] 38%
# - Loading 200 assets: [=======             ] 38%
# - Loading 200 assets: [=======             ] 39%
# - Loading 200 assets: [=======             ] 39%
# - Loading 200 assets: [========            ] 40%
# - Loading 200 assets: [========            ] 40%
# - Loading 200 assets: [========            ] 41%
# - Loading 200 assets: [========            ] 41%
# - Loading 200 assets: [========            ] 42%
# - Loading 200 assets: [========            ] 42%
# - Loading 200 assets: [========            ] 43%
# - Loading 200 assets: [========            ] 43%
# - Loading 200 assets: [========            ] 44%
# - Loading 200 assets: [========            ] 44%
# - Loading 200 assets: [=========           ] 45%
# - Loading 200 assets: [=========           ] 45%
# - Loading 200 assets: [=========           ] 46%
# - Loading 200 assets: [=========           ] 46%
# - Loading 200 assets: [=========           ] 47%
# - Loading 200 assets: [=========           ] 47%
# - Loading 200 assets: [=========           ] 48%
# - Loading 200 assets: [=========           ] 48%
# - Loading 200 assets: [=========           ] 49%
# - Loading 200 assets: [=========           ] 49%
# - Loading 200 assets: [==========          ] 50%
# - Loading 200 assets: [==========          ] 50%
# - Loading 200 assets: [==========          ] 51%
# - Loading 200 assets: [==========          ] 51%
# - Loading 200 assets: [==========          ] 52%
# - Loading 200 assets: [==========          ] 52%
# - Loading 200 assets: [==========          ] 53%
# - Loading 200 assets: [==========          ] 53%
# - Loading 200 assets: [==========          ] 54%
# - Loading 200 assets: [==========          ] 54%
# - Loading 200 assets: [===========         ] 55%
# - Loading 200 assets: [===========         ] 55%
# - Loading 200 assets: [===========         ] 56%
# - Loading 200 assets: [===========         ] 56%
# - Loading 200 assets: [===========         ] 56%
# - Loading 200 assets: [===========         ] 57%
# - Loading 200 assets: [===========         ] 57%
# - Loading 200 assets: [===========         ] 58%
# - Loading 200 assets: [===========         ] 59%
# - Loading 200 assets: [===========         ] 59%
# - Loading 200 assets: [============        ] 60%
# - Loading 200 assets: [============        ] 60%
# - Loading 200 assets: [============        ] 61%
# - Loading 200 assets: [============        ] 61%
# - Loading 200 assets: [============        ] 62%
# - Loading 200 assets: [============        ] 62%
# - Loading 200 assets: [============        ] 63%
# - Loading 200 assets: [============        ] 63%
# - Loading 200 assets: [============        ] 64%
# - Loading 200 assets: [============        ] 64%
# - Loading 200 assets: [=============       ] 65%
# - Loading 200 assets: [=============       ] 65%
# - Loading 200 assets: [=============       ] 66%
# - Loading 200 assets: [=============       ] 66%
# - Loading 200 assets: [=============       ] 67%
# - Loading 200 assets: [=============       ] 67%
# - Loading 200 assets: [=============       ] 68%
# - Loading 200 assets: [=============       ] 68%
# - Loading 200 assets: [=============       ] 69%
# - Loading 200 assets: [=============       ] 69%
# - Loading 200 assets: [==============      ] 70%
# - Loading 200 assets: [==============      ] 70%
# - Loading 200 assets: [==============      ] 71%
# - Loading 200 assets: [==============      ] 71%
# - Loading 200 assets: [==============      ] 72%
# - Loading 200 assets: [==============      ] 72%
# - Loading 200 assets: [==============      ] 73%
# - Loading 200 assets: [==============      ] 73%
# - Loading 200 assets: [==============      ] 74%
# - Loading 200 assets: [==============      ] 74%
# - Loading 200 assets: [===============     ] 75%
# - Loading 200 assets: [===============     ] 75%
# - Loading 200 assets: [===============     ] 76%
# - Loading 200 assets: [===============     ] 76%
# - Loading 200 assets: [===============     ] 77%
# - Loading 200 assets: [===============     ] 77%
# - Loading 200 assets: [===============     ] 78%
# - Loading 200 assets: [===============     ] 78%
# - Loading 200 assets: [===============     ] 79%
# - Loading 200 assets: [===============     ] 79%
# - Loading 200 assets: [================    ] 80%
# - Loading 200 assets: [================    ] 80%
# - Loading 200 assets: [================    ] 81%
# - Loading 200 assets: [================    ] 81%
# - Loading 200 assets: [================    ] 82%
# - Loading 200 assets: [================    ] 82%
# - Loading 200 assets: [================    ] 83%
# - Loading 200 assets: [================    ] 83%
# - Loading 200 assets: [================    ] 84%
# - Loading 200 assets: [================    ] 84%
# - Loading 200 assets: [=================   ] 85%
# - Loading 200 assets: [=================   ] 85%
# - Loading 200 assets: [=================   ] 86%
# - Loading 200 assets: [=================   ] 86%
# - Loading 200 assets: [=================   ] 87%
# - Loading 200 assets: [=================   ] 87%
# - Loading 200 assets: [=================   ] 88%
# - Loading 200 assets: [=================   ] 88%
# - Loading 200 assets: [=================   ] 89%
# - Loading 200 assets: [=================   ] 89%
# - Loading 200 assets: [==================  ] 90%
# - Loading 200 assets: [==================  ] 90%
# - Loading 200 assets: [==================  ] 91%
# - Loading 200 assets: [==================  ] 91%
# - Loading 200 assets: [==================  ] 92%
# - Loading 200 assets: [==================  ] 92%
# - Loading 200 assets: [==================  ] 93%
# - Loading 200 assets: [==================  ] 93%
# - Loading 200 assets: [==================  ] 94%
# - Loading 200 assets: [==================  ] 94%
# - Loading 200 assets: [=================== ] 95%
# - Loading 200 assets: [=================== ] 95%
# - Loading 200 assets: [=================== ] 96%
# - Loading 200 assets: [=================== ] 96%
# - Loading 200 assets: [=================== ] 97%
# - Loading 200 assets: [=================== ] 97%
# - Loading 200 assets: [=================== ] 98%
# - Loading 200 assets: [=================== ] 98%
# - Loading 200 assets: [=================== ] 99%
# - Loading 200 assets: [=================== ] 99%
# - Loading 200 assets: [====================] 100%

# %%
import numpy as np

adjacency_array = np.empty((67, 2), dtype=np.int32)
for i in range(68):
    if i < 34:
        adjacency_array[i, 0] = 34
        adjacency_array[i, 1] = i
    elif i > 34:
        adjacency_array[i-1, 0] = 34
        adjacency_array[i-1, 1] = i

root_vertex = 34

# %%
from cvpr15 import APSBuilder
from menpo.feature import no_op, igo, hog, sparse_hog

# %%
aps = APSBuilder(adjacency_array=None, 
                 root_vertex=0, 
                 features=igo, 
                 patch_shape=(10, 10),
                 normalization_diagonal=200,
                 n_levels=3, 
                 downscale=1.2, 
                 scaled_shape_models=True,
                 max_shape_components=None).build(training_images, verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# - Normalizing images size: 8%
# - Normalizing images size: 8%
# - Normalizing images size: 9%
# - Normalizing images size: 9%
# - Normalizing images size: 10%
# - Normalizing images size: 10%
# - Normalizing images size: 11%
# - Normalizing images size: 11%
# - Normalizing images size: 12%
# - Normalizing images size: 12%
# - Normalizing images size: 13%
# - Normalizing images size: 13%
# - Normalizing images size: 14%
# - Normalizing images size: 14%
# - Normalizing images size: 15%
# - Normalizing images size: 15%
# - Normalizing images size: 16%
# - Normalizing images size: 16%
# - Normalizing images size: 17%
# - Normalizing images size: 17%
# - Normalizing images size: 18%
# - Normalizing images size: 18%
# - Normalizing images size: 19%
# - Normalizing images size: 19%
# - Normalizing images size: 20%
# - Normalizing images size: 20%
# - Normalizing images size: 21%
# - Normalizing images size: 21%
# - Normalizing images size: 22%
# - Normalizing images size: 22%
# - Normalizing images size: 23%
# - Normalizing images size: 23%
# - Normalizing images size: 24%
# - Normalizing images size: 24%
# - Normalizing images size: 25%
# - Normalizing images size: 25%
# - Normalizing images size: 26%
# - Normalizing images size: 26%
# - Normalizing images size: 27%
# - Normalizing images size: 27%
# - Normalizing images size: 28%
# - Normalizing images size: 28%
# - Normalizing images size: 28%
# - Normalizing images size: 29%
# - Normalizing images size: 30%
# - Normalizing images size: 30%
# - Normalizing images size: 31%
# - Normalizing images size: 31%
# - Normalizing images size: 32%
# - Normalizing images size: 32%
# - Normalizing images size: 33%
# - Normalizing images size: 33%
# - Normalizing images size: 34%
# - Normalizing images size: 34%
# - Normalizing images size: 35%
# - Normalizing images size: 35%
# - Normalizing images size: 36%
# - Normalizing images size: 36%
# - Normalizing images size: 37%
# - Normalizing images size: 37%
# - Normalizing images size: 38%
# - Normalizing images size: 38%
# - Normalizing images size: 39%
# - Normalizing images size: 39%
# - Normalizing images size: 40%
# - Normalizing images size: 40%
# - Normalizing images size: 41%
# - Normalizing images size: 41%
# - Normalizing images size: 42%
# - Normalizing images size: 42%
# - Normalizing images size: 43%
# - Normalizing images size: 43%
# - Normalizing images size: 44%
# - Normalizing images size: 44%
# - Normalizing images size: 45%
# - Normalizing images size: 45%
# - Normalizing images size: 46%
# - Normalizing images size: 46%
# - Normalizing images size: 47%
# - Normalizing images size: 47%
# - Normalizing images size: 48%
# - Normalizing images size: 48%
# - Normalizing images size: 49%
# - Normalizing images size: 49%
# - Normalizing images size: 50%
# - Normalizing images size: 50%
# - Normalizing images size: 51%
# - Normalizing images size: 51%
# - Normalizing images size: 52%
# - Normalizing images size: 52%
# - Normalizing images size: 53%
# - Normalizing images size: 53%
# - Normalizing images size: 54%
# - Normalizing images size: 54%
# - Normalizing images size: 55%
# - Normalizing images size: 55%
# - Normalizing images size: 56%
# - Normalizing images size: 56%
# - Normalizing images size: 56%
# - Normalizing images size: 57%
# - Normalizing images size: 57%
# - Normalizing images size: 58%
# - Normalizing images size: 59%
# - Normalizing images size: 59%
# - Normalizing images size: 60%
# - Normalizing images size: 60%
# - Normalizing images size: 61%
# - Normalizing images size: 61%
# - Normalizing images size: 62%
# - Normalizing images size: 62%
# - Normalizing images size: 63%
# - Normalizing images size: 63%
# - Normalizing images size: 64%
# - Normalizing images size: 64%
# - Normalizing images size: 65%
# - Normalizing images size: 65%
# - Normalizing images size: 66%
# - Normalizing images size: 66%
# - Normalizing images size: 67%
# - Normalizing images size: 67%
# - Normalizing images size: 68%
# - Normalizing images size: 68%
# - Normalizing images size: 69%
# - Normalizing images size: 69%
# - Normalizing images size: 70%
# - Normalizing images size: 70%
# - Normalizing images size: 71%
# - Normalizing images size: 71%
# - Normalizing images size: 72%
# - Normalizing images size: 72%
# - Normalizing images size: 73%
# - Normalizing images size: 73%
# - Normalizing images size: 74%
# - Normalizing images size: 74%
# - Normalizing images size: 75%
# - Normalizing images size: 75%
# - Normalizing images size: 76%
# - Normalizing images size: 76%
# - Normalizing images size: 77%
# - Normalizing images size: 77%
# - Normalizing images size: 78%
# - Normalizing images size: 78%
# - Normalizing images size: 79%
# - Normalizing images size: 79%
# - Normalizing images size: 80%
# - Normalizing images size: 80%
# - Normalizing images size: 81%
# - Normalizing images size: 81%
# - Normalizing images size: 82%
# - Normalizing images size: 82%
# - Normalizing images size: 83%
# - Normalizing images size: 83%
# - Normalizing images size: 84%
# - Normalizing images size: 84%
# - Normalizing images size: 85%
# - Normalizing images size: 85%
# - Normalizing images size: 86%
# - Normalizing images size: 86%
# - Normalizing images size: 87%
# - Normalizing images size: 87%
# - Normalizing images size: 88%
# - Normalizing images size: 88%
# - Normalizing images size: 89%
# - Normalizing images size: 89%
# - Normalizing images size: 90%
# - Normalizing images size: 90%
# - Normalizing images size: 91%
# - Normalizing images size: 91%
# - Normalizing images size: 92%
# - Normalizing images size: 92%
# - Normalizing images size: 93%
# - Normalizing images size: 93%
# - Normalizing images size: 94%
# - Normalizing images size: 94%
# - Normalizing images size: 95%
# - Normalizing images size: 95%
# - Normalizing images size: 96%
# - Normalizing images size: 96%
# - Normalizing images size: 97%
# - Normalizing images size: 97%
# - Normalizing images size: 98%
# - Normalizing images size: 98%
# - Normalizing images size: 99%
# - Normalizing images size: 99%
# - Normalizing images size: 100%
# - Normalizing images size: Done
# Computing top level feature space - 0%
# Computing top level feature space - 1%
# Computing top level feature space - 1%
# Computing top level feature space - 2%
# Computing top level feature space - 2%
# Computing top level feature space - 3%
# Computing top level feature space - 3%
# Computing top level feature space - 4%
# Computing top level feature space - 4%
# Computing top level feature space - 5%
# Computing top level feature space - 5%
# Computing top level feature space - 6%
# Computing top level feature space - 6%
# Computing top level feature space - 7%
# Computing top level feature space - 7%
# Computing top level feature space - 8%
# Computing top level feature space - 8%
# Computing top level feature space - 9%
# Computing top level feature space - 9%
# Computing top level feature space - 10%
# Computing top level feature space - 10%
# Computing top level feature space - 11%
# Computing top level feature space - 11%
# Computing top level feature space - 12%
# Computing top level feature space - 12%
# Computing top level feature space - 13%
# Computing top level feature space - 13%
# Computing top level feature space - 14%
# Computing top level feature space - 14%
# Computing top level feature space - 15%
# Computing top level feature space - 15%
# Computing top level feature space - 16%
# Computing top level feature space - 16%
# Computing top level feature space - 17%
# Computing top level feature space - 17%
# Computing top level feature space - 18%
# Computing top level feature space - 18%
# Computing top level feature space - 19%
# Computing top level feature space - 19%
# Computing top level feature space - 20%
# Computing top level feature space - 20%
# Computing top level feature space - 21%
# Computing top level feature space - 21%
# Computing top level feature space - 22%
# Computing top level feature space - 22%
# Computing top level feature space - 23%
# Computing top level feature space - 23%
# Computing top level feature space - 24%
# Computing top level feature space - 24%
# Computing top level feature space - 25%
# Computing top level feature space - 25%
# Computing top level feature space - 26%
# Computing top level feature space - 26%
# Computing top level feature space - 27%
# Computing top level feature space - 27%
# Computing top level feature space - 28%
# Computing top level feature space - 28%
# Computing top level feature space - 28%
# Computing top level feature space - 29%
# Computing top level feature space - 30%
# Computing top level feature space - 30%
# Computing top level feature space - 31%
# Computing top level feature space - 31%
# Computing top level feature space - 32%
# Computing top level feature space - 32%
# Computing top level feature space - 33%
# Computing top level feature space - 33%
# Computing top level feature space - 34%
# Computing top level feature space - 34%
# Computing top level feature space - 35%
# Computing top level feature space - 35%
# Computing top level feature space - 36%
# Computing top level feature space - 36%
# Computing top level feature space - 37%
# Computing top level feature space - 37%
# Computing top level feature space - 38%
# Computing top level feature space - 38%
# Computing top level feature space - 39%
# Computing top level feature space - 39%
# Computing top level feature space - 40%
# Computing top level feature space - 40%
# Computing top level feature space - 41%
# Computing top level feature space - 41%
# Computing top level feature space - 42%
# Computing top level feature space - 42%
# Computing top level feature space - 43%
# Computing top level feature space - 43%
# Computing top level feature space - 44%
# Computing top level feature space - 44%
# Computing top level feature space - 45%
# Computing top level feature space - 45%
# Computing top level feature space - 46%
# Computing top level feature space - 46%
# Computing top level feature space - 47%
# Computing top level feature space - 47%
# Computing top level feature space - 48%
# Computing top level feature space - 48%
# Computing top level feature space - 49%
# Computing top level feature space - 49%
# Computing top level feature space - 50%
# Computing top level feature space - 50%
# Computing top level feature space - 51%
# Computing top level feature space - 51%
# Computing top level feature space - 52%
# Computing top level feature space - 52%
# Computing top level feature space - 53%
# Computing top level feature space - 53%
# Computing top level feature space - 54%
# Computing top level feature space - 54%
# Computing top level feature space - 55%
# Computing top level feature space - 55%
# Computing top level feature space - 56%
# Computing top level feature space - 56%
# Computing top level feature space - 56%
# Computing top level feature space - 57%
# Computing top level feature space - 57%
# Computing top level feature space - 58%
# Computing top level feature space - 59%
# Computing top level feature space - 59%
# Computing top level feature space - 60%
# Computing top level feature space - 60%
# Computing top level feature space - 61%
# Computing top level feature space - 61%
# Computing top level feature space - 62%
# Computing top level feature space - 62%
# Computing top level feature space - 63%
# Computing top level feature space - 63%
# Computing top level feature space - 64%
# Computing top level feature space - 64%
# Computing top level feature space - 65%
# Computing top level feature space - 65%
# Computing top level feature space - 66%
# Computing top level feature space - 66%
# Computing top level feature space - 67%
# Computing top level feature space - 67%
# Computing top level feature space - 68%
# Computing top level feature space - 68%
# Computing top level feature space - 69%
# Computing top level feature space - 69%
# Computing top level feature space - 70%
# Computing top level feature space - 70%
# Computing top level feature space - 71%
# Computing top level feature space - 71%
# Computing top level feature space - 72%
# Computing top level feature space - 72%
# Computing top level feature space - 73%
# Computing top level feature space - 73%
# Computing top level feature space - 74%
# Computing top level feature space - 74%
# Computing top level feature space - 75%
# Computing top level feature space - 75%
# Computing top level feature space - 76%
# Computing top level feature space - 76%
# Computing top level feature space - 77%
# Computing top level feature space - 77%
# Computing top level feature space - 78%
# Computing top level feature space - 78%
# Computing top level feature space - 79%
# Computing top level feature space - 79%
# Computing top level feature space - 80%
# Computing top level feature space - 80%
# Computing top level feature space - 81%
# Computing top level feature space - 81%
# Computing top level feature space - 82%
# Computing top level feature space - 82%
# Computing top level feature space - 83%
# Computing top level feature space - 83%
# Computing top level feature space - 84%
# Computing top level feature space - 84%
# Computing top level feature space - 85%
# Computing top level feature space - 85%
# Computing top level feature space - 86%
# Computing top level feature space - 86%
# Computing top level feature space - 87%
# Computing top level feature space - 87%
# Computing top level feature space - 88%
# Computing top level feature space - 88%
# Computing top level feature space - 89%
# Computing top level feature space - 89%
# Computing top level feature space - 90%
# Computing top level feature space - 90%
# Computing top level feature space - 91%
# Computing top level feature space - 91%
# Computing top level feature space - 92%
# Computing top level feature space - 92%
# Computing top level feature space - 93%
# Computing top level feature space - 93%
# Computing top level feature space - 94%
# Computing top level feature space - 94%
# Computing top level feature space - 95%
# Computing top level feature space - 95%
# Computing top level feature space - 96%
# Computing top level feature space - 96%
# Computing top level feature space - 97%
# Computing top level feature space - 97%
# Computing top level feature space - 98%
# Computing top level feature space - 98%
# Computing top level feature space - 99%
# Computing top level feature space - 99%
# Computing top level feature space - 100%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 0%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 1%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 2%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 3%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 4%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 5%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 6%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 7%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 8%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 9%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 10%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 11%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 12%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 13%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 14%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 15%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 16%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 17%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 18%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 19%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 20%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 21%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 22%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 23%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 24%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 25%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 26%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 27%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 28%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 29%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 30%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 31%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 32%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 33%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# - Computing complete graph`s weights - 34%
# ...
#   - Level 3: Training deformation distribution per edge - 61%
#   - Level 3: Training deformation distribution per edge - 62%
#   - Level 3: Training deformation distribution per edge - 64%
#   - Level 3: Training deformation distribution per edge - 65%
#   - Level 3: Training deformation distribution per edge - 67%
#   - Level 3: Training deformation distribution per edge - 68%
#   - Level 3: Training deformation distribution per edge - 70%
#   - Level 3: Training deformation distribution per edge - 71%
#   - Level 3: Training deformation distribution per edge - 73%
#   - Level 3: Training deformation distribution per edge - 74%
#   - Level 3: Training deformation distribution per edge - 76%
#   - Level 3: Training deformation distribution per edge - 77%
#   - Level 3: Training deformation distribution per edge - 79%
#   - Level 3: Training deformation distribution per edge - 80%
#   - Level 3: Training deformation distribution per edge - 82%
#   - Level 3: Training deformation distribution per edge - 83%
#   - Level 3: Training deformation distribution per edge - 85%
#   - Level 3: Training deformation distribution per edge - 86%
#   - Level 3: Training deformation distribution per edge - 88%
#   - Level 3: Training deformation distribution per edge - 89%
#   - Level 3: Training deformation distribution per edge - 91%
#   - Level 3: Training deformation distribution per edge - 92%
#   - Level 3: Training deformation distribution per edge - 94%
#   - Level 3: Training deformation distribution per edge - 95%
#   - Level 3: Training deformation distribution per edge - 97%
#   - Level 3: Training deformation distribution per edge - 98%
#   - Level 3: Training deformation distribution per edge - 100%
#   - Level 3: Extracting patches from images - 0%
#   - Level 3: Extracting patches from images - 1%
#   - Level 3: Extracting patches from images - 1%
#   - Level 3: Extracting patches from images - 2%
#   - Level 3: Extracting patches from images - 2%
#   - Level 3: Extracting patches from images - 3%
#   - Level 3: Extracting patches from images - 3%
#   - Level 3: Extracting patches from images - 4%
#   - Level 3: Extracting patches from images - 4%
#   - Level 3: Extracting patches from images - 5%
#   - Level 3: Extracting patches from images - 5%
#   - Level 3: Extracting patches from images - 6%
#   - Level 3: Extracting patches from images - 6%
#   - Level 3: Extracting patches from images - 7%
#   - Level 3: Extracting patches from images - 7%
#   - Level 3: Extracting patches from images - 8%
#   - Level 3: Extracting patches from images - 8%
#   - Level 3: Extracting patches from images - 9%
#   - Level 3: Extracting patches from images - 9%
#   - Level 3: Extracting patches from images - 10%
#   - Level 3: Extracting patches from images - 10%
#   - Level 3: Extracting patches from images - 11%
#   - Level 3: Extracting patches from images - 11%
#   - Level 3: Extracting patches from images - 12%
#   - Level 3: Extracting patches from images - 12%
#   - Level 3: Extracting patches from images - 13%
#   - Level 3: Extracting patches from images - 13%
#   - Level 3: Extracting patches from images - 14%
#   - Level 3: Extracting patches from images - 14%
#   - Level 3: Extracting patches from images - 15%
#   - Level 3: Extracting patches from images - 15%
#   - Level 3: Extracting patches from images - 16%
#   - Level 3: Extracting patches from images - 16%
#   - Level 3: Extracting patches from images - 17%
#   - Level 3: Extracting patches from images - 17%
#   - Level 3: Extracting patches from images - 18%
#   - Level 3: Extracting patches from images - 18%
#   - Level 3: Extracting patches from images - 19%
#   - Level 3: Extracting patches from images - 19%
#   - Level 3: Extracting patches from images - 20%
#   - Level 3: Extracting patches from images - 20%
#   - Level 3: Extracting patches from images - 21%
#   - Level 3: Extracting patches from images - 21%
#   - Level 3: Extracting patches from images - 22%
#   - Level 3: Extracting patches from images - 22%
#   - Level 3: Extracting patches from images - 23%
#   - Level 3: Extracting patches from images - 23%
#   - Level 3: Extracting patches from images - 24%
#   - Level 3: Extracting patches from images - 24%
#   - Level 3: Extracting patches from images - 25%
#   - Level 3: Extracting patches from images - 25%
#   - Level 3: Extracting patches from images - 26%
#   - Level 3: Extracting patches from images - 26%
#   - Level 3: Extracting patches from images - 27%
#   - Level 3: Extracting patches from images - 27%
#   - Level 3: Extracting patches from images - 28%
#   - Level 3: Extracting patches from images - 28%
#   - Level 3: Extracting patches from images - 28%
#   - Level 3: Extracting patches from images - 29%
#   - Level 3: Extracting patches from images - 30%
#   - Level 3: Extracting patches from images - 30%
#   - Level 3: Extracting patches from images - 31%
#   - Level 3: Extracting patches from images - 31%
#   - Level 3: Extracting patches from images - 32%
#   - Level 3: Extracting patches from images - 32%
#   - Level 3: Extracting patches from images - 33%
#   - Level 3: Extracting patches from images - 33%
#   - Level 3: Extracting patches from images - 34%
#   - Level 3: Extracting patches from images - 34%
#   - Level 3: Extracting patches from images - 35%
#   - Level 3: Extracting patches from images - 35%
#   - Level 3: Extracting patches from images - 36%
#   - Level 3: Extracting patches from images - 36%
#   - Level 3: Extracting patches from images - 37%
#   - Level 3: Extracting patches from images - 37%
#   - Level 3: Extracting patches from images - 38%
#   - Level 3: Extracting patches from images - 38%
#   - Level 3: Extracting patches from images - 39%
#   - Level 3: Extracting patches from images - 39%
#   - Level 3: Extracting patches from images - 40%
#   - Level 3: Extracting patches from images - 40%
#   - Level 3: Extracting patches from images - 41%
#   - Level 3: Extracting patches from images - 41%
#   - Level 3: Extracting patches from images - 42%
#   - Level 3: Extracting patches from images - 42%
#   - Level 3: Extracting patches from images - 43%
#   - Level 3: Extracting patches from images - 43%
#   - Level 3: Extracting patches from images - 44%
#   - Level 3: Extracting patches from images - 44%
#   - Level 3: Extracting patches from images - 45%
#   - Level 3: Extracting patches from images - 45%
#   - Level 3: Extracting patches from images - 46%
#   - Level 3: Extracting patches from images - 46%
#   - Level 3: Extracting patches from images - 47%
#   - Level 3: Extracting patches from images - 47%
#   - Level 3: Extracting patches from images - 48%
#   - Level 3: Extracting patches from images - 48%
#   - Level 3: Extracting patches from images - 49%
#   - Level 3: Extracting patches from images - 49%
#   - Level 3: Extracting patches from images - 50%
#   - Level 3: Extracting patches from images - 50%
#   - Level 3: Extracting patches from images - 51%
#   - Level 3: Extracting patches from images - 51%
#   - Level 3: Extracting patches from images - 52%
#   - Level 3: Extracting patches from images - 52%
#   - Level 3: Extracting patches from images - 53%
#   - Level 3: Extracting patches from images - 53%
#   - Level 3: Extracting patches from images - 54%
#   - Level 3: Extracting patches from images - 54%
#   - Level 3: Extracting patches from images - 55%
#   - Level 3: Extracting patches from images - 55%
#   - Level 3: Extracting patches from images - 56%
#   - Level 3: Extracting patches from images - 56%
#   - Level 3: Extracting patches from images - 56%
#   - Level 3: Extracting patches from images - 57%
#   - Level 3: Extracting patches from images - 57%
#   - Level 3: Extracting patches from images - 58%
#   - Level 3: Extracting patches from images - 59%
#   - Level 3: Extracting patches from images - 59%
#   - Level 3: Extracting patches from images - 60%
#   - Level 3: Extracting patches from images - 60%
#   - Level 3: Extracting patches from images - 61%
#   - Level 3: Extracting patches from images - 61%
#   - Level 3: Extracting patches from images - 62%
#   - Level 3: Extracting patches from images - 62%
#   - Level 3: Extracting patches from images - 63%
#   - Level 3: Extracting patches from images - 63%
#   - Level 3: Extracting patches from images - 64%
#   - Level 3: Extracting patches from images - 64%
#   - Level 3: Extracting patches from images - 65%
#   - Level 3: Extracting patches from images - 65%
#   - Level 3: Extracting patches from images - 66%
#   - Level 3: Extracting patches from images - 66%
#   - Level 3: Extracting patches from images - 67%
#   - Level 3: Extracting patches from images - 67%
#   - Level 3: Extracting patches from images - 68%
#   - Level 3: Extracting patches from images - 68%
#   - Level 3: Extracting patches from images - 69%
#   - Level 3: Extracting patches from images - 69%
#   - Level 3: Extracting patches from images - 70%
#   - Level 3: Extracting patches from images - 70%
#   - Level 3: Extracting patches from images - 71%
#   - Level 3: Extracting patches from images - 71%
#   - Level 3: Extracting patches from images - 72%
#   - Level 3: Extracting patches from images - 72%
#   - Level 3: Extracting patches from images - 73%
#   - Level 3: Extracting patches from images - 73%
#   - Level 3: Extracting patches from images - 74%
#   - Level 3: Extracting patches from images - 74%
#   - Level 3: Extracting patches from images - 75%
#   - Level 3: Extracting patches from images - 75%
#   - Level 3: Extracting patches from images - 76%
#   - Level 3: Extracting patches from images - 76%
#   - Level 3: Extracting patches from images - 77%
#   - Level 3: Extracting patches from images - 77%
#   - Level 3: Extracting patches from images - 78%
#   - Level 3: Extracting patches from images - 78%
#   - Level 3: Extracting patches from images - 79%
#   - Level 3: Extracting patches from images - 79%
#   - Level 3: Extracting patches from images - 80%
#   - Level 3: Extracting patches from images - 80%
#   - Level 3: Extracting patches from images - 81%
#   - Level 3: Extracting patches from images - 81%
#   - Level 3: Extracting patches from images - 82%
#   - Level 3: Extracting patches from images - 82%
#   - Level 3: Extracting patches from images - 83%
#   - Level 3: Extracting patches from images - 83%
#   - Level 3: Extracting patches from images - 84%
#   - Level 3: Extracting patches from images - 84%
#   - Level 3: Extracting patches from images - 85%
#   - Level 3: Extracting patches from images - 85%
#   - Level 3: Extracting patches from images - 86%
#   - Level 3: Extracting patches from images - 86%
#   - Level 3: Extracting patches from images - 87%
#   - Level 3: Extracting patches from images - 87%
#   - Level 3: Extracting patches from images - 88%
#   - Level 3: Extracting patches from images - 88%
#   - Level 3: Extracting patches from images - 89%
#   - Level 3: Extracting patches from images - 89%
#   - Level 3: Extracting patches from images - 90%
#   - Level 3: Extracting patches from images - 90%
#   - Level 3: Extracting patches from images - 91%
#   - Level 3: Extracting patches from images - 91%
#   - Level 3: Extracting patches from images - 92%
#   - Level 3: Extracting patches from images - 92%
#   - Level 3: Extracting patches from images - 93%
#   - Level 3: Extracting patches from images - 93%
#   - Level 3: Extracting patches from images - 94%
#   - Level 3: Extracting patches from images - 94%
#   - Level 3: Extracting patches from images - 95%
#   - Level 3: Extracting patches from images - 95%
#   - Level 3: Extracting patches from images - 96%
#   - Level 3: Extracting patches from images - 96%
#   - Level 3: Extracting patches from images - 97%
#   - Level 3: Extracting patches from images - 97%
#   - Level 3: Extracting patches from images - 98%
#   - Level 3: Extracting patches from images - 98%
#   - Level 3: Extracting patches from images - 99%
#   - Level 3: Extracting patches from images - 99%
#   - Level 3: Extracting patches from images - 100%
#   - Level 3: Training appearance distribution per patch
#   - Level 3: Training appearance distribution per patch - 1%
#   - Level 3: Training appearance distribution per patch - 2%
#   - Level 3: Training appearance distribution per patch - 4%
#   - Level 3: Training appearance distribution per patch - 5%
#   - Level 3: Training appearance distribution per patch - 7%
#   - Level 3: Training appearance distribution per patch - 8%
#   - Level 3: Training appearance distribution per patch - 10%
#   - Level 3: Training appearance distribution per patch - 11%
#   - Level 3: Training appearance distribution per patch - 13%
#   - Level 3: Training appearance distribution per patch - 14%
#   - Level 3: Training appearance distribution per patch - 16%
#   - Level 3: Training appearance distribution per patch - 17%
#   - Level 3: Training appearance distribution per patch - 19%
#   - Level 3: Training appearance distribution per patch - 20%
#   - Level 3: Training appearance distribution per patch - 22%
#   - Level 3: Training appearance distribution per patch - 23%
#   - Level 3: Training appearance distribution per patch - 25%
#   - Level 3: Training appearance distribution per patch - 26%
#   - Level 3: Training appearance distribution per patch - 27%
#   - Level 3: Training appearance distribution per patch - 29%
#   - Level 3: Training appearance distribution per patch - 30%
#   - Level 3: Training appearance distribution per patch - 32%
#   - Level 3: Training appearance distribution per patch - 33%
#   - Level 3: Training appearance distribution per patch - 35%
#   - Level 3: Training appearance distribution per patch - 36%
#   - Level 3: Training appearance distribution per patch - 38%
#   - Level 3: Training appearance distribution per patch - 39%
#   - Level 3: Training appearance distribution per patch - 41%
#   - Level 3: Training appearance distribution per patch - 42%
#   - Level 3: Training appearance distribution per patch - 44%
#   - Level 3: Training appearance distribution per patch - 45%
#   - Level 3: Training appearance distribution per patch - 47%
#   - Level 3: Training appearance distribution per patch - 48%
#   - Level 3: Training appearance distribution per patch - 50%
#   - Level 3: Training appearance distribution per patch - 51%
#   - Level 3: Training appearance distribution per patch - 52%
#   - Level 3: Training appearance distribution per patch - 54%
#   - Level 3: Training appearance distribution per patch - 55%
#   - Level 3: Training appearance distribution per patch - 57%
#   - Level 3: Training appearance distribution per patch - 58%
#   - Level 3: Training appearance distribution per patch - 60%
#   - Level 3: Training appearance distribution per patch - 61%
#   - Level 3: Training appearance distribution per patch - 63%
#   - Level 3: Training appearance distribution per patch - 64%
#   - Level 3: Training appearance distribution per patch - 66%
#   - Level 3: Training appearance distribution per patch - 67%
#   - Level 3: Training appearance distribution per patch - 69%
#   - Level 3: Training appearance distribution per patch - 70%
#   - Level 3: Training appearance distribution per patch - 72%
#   - Level 3: Training appearance distribution per patch - 73%
#   - Level 3: Training appearance distribution per patch - 75%
#   - Level 3: Training appearance distribution per patch - 76%
#   - Level 3: Training appearance distribution per patch - 77%
#   - Level 3: Training appearance distribution per patch - 79%
#   - Level 3: Training appearance distribution per patch - 80%
#   - Level 3: Training appearance distribution per patch - 82%
#   - Level 3: Training appearance distribution per patch - 83%
#   - Level 3: Training appearance distribution per patch - 85%
#   - Level 3: Training appearance distribution per patch - 86%
#   - Level 3: Training appearance distribution per patch - 88%
#   - Level 3: Training appearance distribution per patch - 89%
#   - Level 3: Training appearance distribution per patch - 91%
#   - Level 3: Training appearance distribution per patch - 92%
#   - Level 3: Training appearance distribution per patch - 94%
#   - Level 3: Training appearance distribution per patch - 95%
#   - Level 3: Training appearance distribution per patch - 97%
#   - Level 3: Training appearance distribution per patch - 98%
#   - Level 3: Training appearance distribution per patch - 100%
#   - Level 3: Done

# %%
from menpofit.visualize import visualize_shape_model
# %matplotlib inline
visualize_shape_model(aps.shape_models)

# %%
aps.random_instance(as_tree=True).view()

# %%
from cvpr15.fitter import LucasKanadeAPSFitter
from cvpr15.algorithm import Forward

fitter = LucasKanadeAPSFitter(aps, 
                              algorithm=Forward, 
                              n_shape=[5, 10, 15], 
                              n_appearance=None)

# %%
im = training_images[0]
gt_shape = im.landmarks['PTS'].lms
initial_shape = fitter.perturb_shape(gt_shape, noise_std=0.02)

fr = fitter.fit(im, initial_shape, gt_shape=gt_shape)
# Out:
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 9 x 9
# H^-1: 9 x 9
# J_a: 1700 x 9
# J_a^T * S_a: 9 x 1700
# e: 1700
# h_s: 9 x 9
# p: 9
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 14 x 14
# H^-1: 14 x 14
# J_a: 1700 x 14
# J_a^T * S_a: 14 x 1700
# e: 1700
# h_s: 14 x 14
# p: 14
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19
# H: 19 x 19
# H^-1: 19 x 19
# J_a: 1700 x 19
# J_a^T * S_a: 19 x 1700
# e: 1700
# h_s: 19 x 19
# p: 19

# %%
from menpofit.visualize import visualize_fitting_results
# %matplotlib inline
visualize_fitting_results(fr)

# %%
a = fitter._fitters[0]

# %%
a.transform.model.components.shape
# Out:
# (5, 136)

# %%
a.transform.model.mean().view()

# %%
import numpy as np
print np.rollaxis(a.transform.d_dp(None), -1).shape
# Out:
# (2, 68, 9)
